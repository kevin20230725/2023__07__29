# %%
#lesson14_1

# %%
#寫程式下載檔案
#json為純文字，複雜
import requests
url = 'https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'
r = requests.get(url)
if r.status_code == 200:        #r.status_code == 200 檔案正常
    print("下載成功")
# Out:
# 下載成功

# %%
all_json = r.json()
locations = all_json['cwaopendata']['dataset']['location']
#先建立一維空list，裡面存dict
weather_list = []
for item in locations:
    #建立dict
    city_item = {}
    city_item['城市'] = item['locationName']
    city_item['起始時間'] = item["weatherElement"][1]['time'][0]['startTime']
    city_item['結束時間'] = item["weatherElement"][1]['time'][0]['endTime']
    city_item['最高溫度'] = float(item["weatherElement"][1]['time'][0]['parameter']['parameterName'])
    city_item['最低溫度'] = float(item["weatherElement"][2]['time'][0]['parameter']['parameterName'])
    city_item['體感'] = item["weatherElement"][3]['time'][0]['parameter']['parameterName']

    weather_list.append(city_item)
weather_list
# Out:
# [{'城市': '臺北市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 22.0,
#   '最低溫度': 17.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '新北市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 23.0,
#   '最低溫度': 18.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '桃園市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 22.0,
#   '最低溫度': 17.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '臺中市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 25.0,
#   '最低溫度': 19.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '臺南市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 25.0,
#   '最低溫度': 21.0,
#   '體感': '舒適'},
#  {'城市': '高雄市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 27.0,
#   '最低溫度': 21.0,
#   '體感': '舒適'},
#  {'城市': '基隆市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 20.0,
#   '最低溫度': 17.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '新竹縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 22.0,
#   '最低溫度': 16.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '新竹市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 22.0,
#   '最低溫度': 16.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '苗栗縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 23.0,
#   '最低溫度': 17.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '彰化縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 25.0,
#   '最低溫度': 19.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '南投縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 26.0,
#   '最低溫度': 19.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '雲林縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 25.0,
#   '最低溫度': 19.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '嘉義縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 26.0,
#   '最低溫度': 20.0,
#   '體感': '舒適'},
#  {'城市': '嘉義市',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 26.0,
#   '最低溫度': 19.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '屏東縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 28.0,
#   '最低溫度': 21.0,
#   '體感': '舒適'},
#  {'城市': '宜蘭縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 23.0,
#   '最低溫度': 19.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '花蓮縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 23.0,
#   '最低溫度': 19.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '臺東縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 25.0,
#   '最低溫度': 21.0,
#   '體感': '舒適'},
#  {'城市': '澎湖縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 21.0,
#   '最低溫度': 19.0,
#   '體感': '稍有寒意至舒適'},
#  {'城市': '金門縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 18.0,
#   '最低溫度': 14.0,
#   '體感': '寒冷至稍有寒意'},
#  {'城市': '連江縣',
#   '起始時間': '2024-03-17T18:00:00+08:00',
#   '結束時間': '2024-03-18T06:00:00+08:00',
#   '最高溫度': 13.0,
#   '最低溫度': 11.0,
#   '體感': '寒冷'}]

# %%
import pandas as pd
weaather_df = pd.DataFrame(weather_list)
weaather_df
# Out:
#      城市                       起始時間                       結束時間  最高溫度  最低溫度  \
# 0   臺北市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  22.0  17.0
# 1   新北市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  23.0  18.0
# 2   桃園市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  22.0  17.0
# 3   臺中市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  25.0  19.0
# 4   臺南市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  25.0  21.0
# 5   高雄市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  27.0  21.0
# 6   基隆市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  20.0  17.0
# 7   新竹縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  22.0  16.0
# 8   新竹市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  22.0  16.0
# 9   苗栗縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  23.0  17.0
# 10  彰化縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  25.0  19.0
# 11  南投縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  26.0  19.0
# 12  雲林縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  25.0  19.0
# 13  嘉義縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  26.0  20.0
# 14  嘉義市  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  26.0  19.0
# 15  屏東縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  28.0  21.0
# 16  宜蘭縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  23.0  19.0
# 17  花蓮縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  23.0  19.0
# 18  臺東縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  25.0  21.0
# 19  澎湖縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  21.0  19.0
# 20  金門縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  18.0  14.0
# 21  連江縣  2024-03-17T18:00:00+08:00  2024-03-18T06:00:00+08:00  13.0  11.0
#
#          體感
# 0   稍有寒意至舒適
# 1   稍有寒意至舒適
# 2   稍有寒意至舒適
# 3   稍有寒意至舒適
# 4        舒適
# 5        舒適
# 6   稍有寒意至舒適
# 7   稍有寒意至舒適
# 8   稍有寒意至舒適
# 9   稍有寒意至舒適
# 10  稍有寒意至舒適
# 11  稍有寒意至舒適
# 12  稍有寒意至舒適
# 13       舒適
# 14  稍有寒意至舒適
# 15       舒適
# 16  稍有寒意至舒適
# 17  稍有寒意至舒適
# 18       舒適
# 19  稍有寒意至舒適
# 20  寒冷至稍有寒意
# 21       寒冷
