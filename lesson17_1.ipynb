# %%
import pandas as pd
data = {'字串':['台北','台中'],
        "整數":[1000,3000],
        "浮點數":[3.258,7.396]}
df = pd.DataFrame(data)
display(df)
# Out:
#    字串    整數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化
#需先下載 jinja2
#pip install jinja2
df.style.\
format(precision=2,thousands=',',decimal='.')\
.relabel_index(["列1",'列2'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_11f35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11f35_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_11f35_level0_col1" class="col_heading level0 col1" >整數</th>
#       <th id="T_11f35_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11f35_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_11f35_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_11f35_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_11f35_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_11f35_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_11f35_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_11f35_row1_col1" class="data row1 col1" >3,000</td>
#       <td id="T_11f35_row1_col2" class="data row1 col2" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
import pandas as pd
data = np.random.rand(10,2) * 5
df = pd.DataFrame(data,
             index = pd.date_range(start='20240324',periods=10),
             columns = ['台北','台中']
             )
df
# Out:
#                   台北        台中
# 2024-03-24  1.054539  3.402551
# 2024-03-25  2.378512  1.716330
# 2024-03-26  0.410519  4.864817
# 2024-03-27  0.022196  0.861612
# 2024-03-28  1.332255  4.425238
# 2024-03-29  0.378413  4.898319
# 2024-03-30  0.828776  0.177354
# 2024-03-31  2.552788  3.674341
# 2024-04-01  2.153046  4.009048
# 2024-04-02  4.446656  3.875284

# %%
#pd.date_range() 函數測試
pd.date_range(start='2024-1-1',end='2024-1-10')
pd.date_range(start='2024-01-01', periods=10)
#以一周7天為單位，輸出每周最後一天的日期
pd.date_range(start='2024-01-01', end='2024-12-31', freq='W')
#以月為單位，輸出每月最後一天的日期
pd.date_range(start='2024-01-01', end='2024-12-31', freq='ME')
#以月為單位，輸出每月最後一個工作日的日期
pd.date_range(start='2024-01-01', end='2024-12-31', freq='BME')
#
pd.date_range(start='2024-01-01', end='2024-12-31', tz='UTC')

#pd.date_range() 日期參數有格式要求
#ISO 8601 标准日期格式：'YYYY-MM-DD'
#美国日期格式：'MM/DD/YYYY'
#欧洲日期格式：'DD/MM/YYYY'
#其他常见日期格式
# Out:
# DatetimeIndex(['2024-01-31', '2024-02-29', '2024-03-29', '2024-04-30',
#                '2024-05-31', '2024-06-28', '2024-07-31', '2024-08-30',
#                '2024-09-30', '2024-10-31', '2024-11-29', '2024-12-31'],
#               dtype='datetime64[ns]', freq='BME')

# %%
#視覺美化資料表
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮濕"
    else :
        return "日曬"

df.style.format(feel_condition).set_caption("體感溫度").background_gradient(cmap="PuBuGn",vmin=1,vmax=5,axis=None)
# Out:
# <style type="text/css">
# #T_53685_row0_col0 {
#   background-color: #016d5b;
#   color: #f1f1f1;
# }
# #T_53685_row0_col1, #T_53685_row2_col1 {
#   background-color: #60a5cd;
#   color: #f1f1f1;
# }
# #T_53685_row1_col0, #T_53685_row3_col0, #T_53685_row4_col0, #T_53685_row7_col1, #T_53685_row8_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_53685_row1_col1 {
#   background-color: #9fbbda;
#   color: #000000;
# }
# #T_53685_row2_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_53685_row3_col1 {
#   background-color: #ded9eb;
#   color: #000000;
# }
# #T_53685_row4_col1 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_53685_row5_col0 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_53685_row5_col1 {
#   background-color: #8cb5d6;
#   color: #000000;
# }
# #T_53685_row6_col0 {
#   background-color: #ece2f0;
#   color: #000000;
# }
# #T_53685_row6_col1 {
#   background-color: #027978;
#   color: #f1f1f1;
# }
# #T_53685_row7_col0 {
#   background-color: #0b8393;
#   color: #f1f1f1;
# }
# #T_53685_row8_col0 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_53685_row9_col0 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_53685_row9_col1 {
#   background-color: #78aed2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_53685">
#   <caption>體感溫度</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53685_level0_col0" class="col_heading level0 col0" >台北</th>
#       <th id="T_53685_level0_col1" class="col_heading level0 col1" >台中</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53685_level0_row0" class="row_heading level0 row0" >2024-03-24 00:00:00</th>
#       <td id="T_53685_row0_col0" class="data row0 col0" >日曬</td>
#       <td id="T_53685_row0_col1" class="data row0 col1" >日曬</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row1" class="row_heading level0 row1" >2024-03-25 00:00:00</th>
#       <td id="T_53685_row1_col0" class="data row1 col0" >溫暖</td>
#       <td id="T_53685_row1_col1" class="data row1 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row2" class="row_heading level0 row2" >2024-03-26 00:00:00</th>
#       <td id="T_53685_row2_col0" class="data row2 col0" >潮濕</td>
#       <td id="T_53685_row2_col1" class="data row2 col1" >日曬</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row3" class="row_heading level0 row3" >2024-03-27 00:00:00</th>
#       <td id="T_53685_row3_col0" class="data row3 col0" >溫暖</td>
#       <td id="T_53685_row3_col1" class="data row3 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row4" class="row_heading level0 row4" >2024-03-28 00:00:00</th>
#       <td id="T_53685_row4_col0" class="data row4 col0" >溫暖</td>
#       <td id="T_53685_row4_col1" class="data row4 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row5" class="row_heading level0 row5" >2024-03-29 00:00:00</th>
#       <td id="T_53685_row5_col0" class="data row5 col0" >潮濕</td>
#       <td id="T_53685_row5_col1" class="data row5 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row6" class="row_heading level0 row6" >2024-03-30 00:00:00</th>
#       <td id="T_53685_row6_col0" class="data row6 col0" >溫暖</td>
#       <td id="T_53685_row6_col1" class="data row6 col1" >日曬</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row7" class="row_heading level0 row7" >2024-03-31 00:00:00</th>
#       <td id="T_53685_row7_col0" class="data row7 col0" >日曬</td>
#       <td id="T_53685_row7_col1" class="data row7 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row8" class="row_heading level0 row8" >2024-04-01 00:00:00</th>
#       <td id="T_53685_row8_col0" class="data row8 col0" >溫暖</td>
#       <td id="T_53685_row8_col1" class="data row8 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_53685_level0_row9" class="row_heading level0 row9" >2024-04-02 00:00:00</th>
#       <td id="T_53685_row9_col0" class="data row9 col0" >潮濕</td>
#       <td id="T_53685_row9_col1" class="data row9 col1" >日曬</td>
#     </tr>
#   </tbody>
# </table>

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5))
df.style.\
hide(subset=[0,2,4],axis=0)\
.hide(subset=[1,3],axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e9d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e9d9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_0e9d9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_0e9d9_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e9d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e9d9_row1_col0" class="data row1 col0" >0.473386</td>
#       <td id="T_0e9d9_row1_col2" class="data row1 col2" >-0.464674</td>
#       <td id="T_0e9d9_row1_col4" class="data row1 col4" >0.320238</td>
#     </tr>
#     <tr>
#       <th id="T_0e9d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0e9d9_row3_col0" class="data row3 col0" >0.997247</td>
#       <td id="T_0e9d9_row3_col2" class="data row3 col2" >1.296173</td>
#       <td id="T_0e9d9_row3_col4" class="data row3 col4" >-0.919566</td>
#     </tr>
#   </tbody>
# </table>
