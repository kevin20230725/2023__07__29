# %%
#下載檔案
#import requests
import requests
url = 'https://sheethub.com/data.gov.tw/%E5%90%84%E9%84%89%E9%8Е%AE%E5%B8%82&Е5%8D%80%E4%BA%BA%E5%8F%A3%E5%AF%86%E5%BA%A6?format=csv'

response = requests.request('Get',url)
#r.status_code == 200 檔案正常
if r.status_code == 200:
    print("下載成功")
# Out:
# <Response [404]>

# %%
from io import StringIO
import csv

file = StringIO(response.txt)
csv_reader = csv.reader(file)
data = list(csv_reader)
data

# %%
#以上網址錯誤，無法下載執行
#改採以下直接讀取Excel的方式

# %%
import csv
import pandas as pd
frame = pd.read_csv('各鄉鎮市區人口密度.csv')
frame.columns = frame.iloc[0]
frame1 = frame.drop(index=0)
frame1
frame2 = frame1.reindex(index=range(1,371))
frame2
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
frame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 1 to 370
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     370 non-null    object
#  1   區域別     370 non-null    object
#  2   年底人口數   370 non-null    object
#  3   土地面積    370 non-null    object
#  4   人口密度    370 non-null    object
# dtypes: object(5)
# memory usage: 14.6+ KB

# %%
frame2.index = frame2['區域別']
frame2[['年底人口數','土地面積','人口密度']]
# Out:
# 0        年底人口數     土地面積   人口密度
# 區域別
# 新北市板橋區  551480  23.1373  23835
# 新北市三重區  387484   16.317  23747
# 新北市中和區  413590   20.144  20532
# 新北市永和區  222585   5.7138  38956
# 新北市新莊區  416524  19.7383  21102
# ...        ...      ...    ...
# 連江縣北竿鄉    2360      9.9    238
# 連江縣莒光鄉    1624      4.7    346
# 連江縣東引鄉    1352      3.8    356
# 東沙群島        …      2.38     …
# 南沙群島        …    0.5045     …
#
# [370 rows x 3 columns]

# %%
#frame2[['年底人口數','土地面積','人口密度']]
f2 = frame2.reindex(columns=['年底人口數','土地面積','人口密度'])
f2
# Out:
# 0        年底人口數     土地面積   人口密度
# 區域別
# 新北市板橋區  551480  23.1373  23835
# 新北市三重區  387484   16.317  23747
# 新北市中和區  413590   20.144  20532
# 新北市永和區  222585   5.7138  38956
# 新北市新莊區  416524  19.7383  21102
# ...        ...      ...    ...
# 連江縣北竿鄉    2360      9.9    238
# 連江縣莒光鄉    1624      4.7    346
# 連江縣東引鄉    1352      3.8    356
# 東沙群島        …      2.38     …
# 南沙群島        …    0.5045     …
#
# [370 rows x 3 columns]

# %%
f2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 370 entries, 新北市板橋區 to 南沙群島
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   年底人口數   370 non-null    object
#  1   土地面積    370 non-null    object
#  2   人口密度    370 non-null    object
# dtypes: object(3)
# memory usage: 11.6+ KB

# %%
#f2['年底人口數'].astype(int)
#… 
f2.query('年底人口數=="… "')        #f2[f2['年底人口數'] == "… "]
# Out:
# 0    年底人口數    土地面積 人口密度
# 區域別
# 東沙群島    …     2.38   …
# 南沙群島    …   0.5045   …

# %%
frame3 = f2.drop(index=['東沙群島','南沙群島'])
frame3
# Out:
# 0        年底人口數     土地面積   人口密度
# 區域別
# 新北市板橋區  551480  23.1373  23835
# 新北市三重區  387484   16.317  23747
# 新北市中和區  413590   20.144  20532
# 新北市永和區  222585   5.7138  38956
# 新北市新莊區  416524  19.7383  21102
# ...        ...      ...    ...
# 金門縣烏坵鄉     685      1.2    571
# 連江縣南竿鄉    7544     10.4    725
# 連江縣北竿鄉    2360      9.9    238
# 連江縣莒光鄉    1624      4.7    346
# 連江縣東引鄉    1352      3.8    356
#
# [368 rows x 3 columns]

# %%
frame3['年底人口數'] = frame3['年底人口數'].astype(int)

# %%
frame3['土地面積'] = frame3['土地面積'].astype(float)

# %%
frame3['人口密度'] = frame3['人口密度'].astype(int)

# %%
display(frame3)
frame3.info()
# Out:
# 0        年底人口數     土地面積   人口密度
# 區域別
# 新北市板橋區  551480  23.1373  23835
# 新北市三重區  387484  16.3170  23747
# 新北市中和區  413590  20.1440  20532
# 新北市永和區  222585   5.7138  38956
# 新北市新莊區  416524  19.7383  21102
# ...        ...      ...    ...
# 金門縣烏坵鄉     685   1.2000    571
# 連江縣南竿鄉    7544  10.4000    725
# 連江縣北竿鄉    2360   9.9000    238
# 連江縣莒光鄉    1624   4.7000    346
# 連江縣東引鄉    1352   3.8000    356
#
# [368 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 368 entries, 新北市板橋區 to 連江縣東引鄉
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   年底人口數   368 non-null    int64
#  1   土地面積    368 non-null    float64
#  2   人口密度    368 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 19.6+ KB
